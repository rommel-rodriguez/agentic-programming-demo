# %%
# Import path configuration
from pathlib import Path
import sys
import logging
from dotenv import load_dotenv

from langchain_core.messages import (
    AIMessage,
    AnyMessage,
    HumanMessage,
    SystemMessage,
    ToolMessage,
)
load_dotenv()
logger  = logging.getLogger(__name__)

def _find_project_root(start: Path) -> Path:
    for parent in [start, *start.parents]:
        if (parent/"pyproject.toml").exists():
            return parent
    raise RuntimeError("Project root not found")

ROOT = _find_project_root(Path.cwd())
SRC = ROOT / "src"

if str(SRC) not in sys.path:
    sys.path.insert(0, str(SRC))

# %%
from app.utils.test import print_something
from app.adapters.invoice_parsing_agent import InvoiceParsingAgent, MODEL
from app.config import configure_logging

# %%
configure_logging()

# %%
from pypdf import PdfReader

def pdf_to_text(pdf_path: str, max_chars: int = 40_000) -> str:
    reader = PdfReader(pdf_path)
    chunks = []
    for i, page in enumerate(reader.pages):
        t = page.extract_text() or ""
        chunks.append(f"\n\n--- Page {i+1} ---\n{t}")
        if sum(len(c) for c in chunks) >= max_chars:
            break
    return "".join(chunks)[:max_chars]

# %%
invoice_text = pdf_to_text("./invoices/invoice01.pdf")
invoice_text
# Out:
# '\n\n--- Page 1 ---\nIntegratel Perú S.A.A.   |   R.U.C. 20100017491   |   Jr. Domingo Martínez Luján N° 1130   |   Lima \x96 Lima - SurquilloPágina 1/3\nMovistar HogarRecibo EneroESTHER RENE PEREZ CASTILLODNI: 06198154 ---..Mz.S/Lt.14URBANIZACIONRESIDENCIALLOSJAZMINESDELNARANJAL, LOS OLIVOS, LIMA, LIMACuenta financiera: 603306704Teléfonos asociados: 15233543\nTotal a pagarS/159.90Último día de pago: 05/02N° Fijo / Cód. pago: 15233543\n Pagaatiempotureciboymantentesiempreconectado.No esperes hasta el último día de pago.\nCiclo de facturación - Enero 202618/01 05/02Fecha deEmisiónÚltimo díade pago\n¡AHORRA!¡PagatureciboMovistardeformadigital,evitacomisionesytenmásbeneficios!esrápido,fácilyseguro.Ahorapuedes pagar con YAPE\nResumen del recibo - Nº S5AA-0077300973\nTrio Mov. Voz Int. Full HD RA AG24S/ 159.90\nDescuentos y Bonificaciones Inafectos S/ 0.00\nRedondeo S/ 0.00Devoluciones S/ 0.00Débitos S/ 0.00Deuda pasada S/ 0.00Total a pagarS/ 159.90\n\n--- Page 2 ---\nMovistar Hogar\nIntegratel Perú S.A.A.   |   R.U.C. 20100017491   |   Jr. Domingo Martínez Luján N° 1130   |   Lima \x96 Lima - SurquilloPágina 2/3\nAnexo 1: 15233543\nTrio Mov. Voz Int. Full HD RA AG24Precio de vta.IGVS/159.90Movistar Internet 200 Mbps (18Ene al 17Feb) 59.2410.66 69.90Movistar Voz (18Ene al 17Feb) 8.47 1.53 10.00Movistar TV Full (18Ene al 17Feb) 56.3610.14 66.50Bloque Full HD INC (18Ene al 17Feb) 11.44 2.06 13.50\nDescuentos y Bonificaciones Inafectos Precio de vta.IGVS/0.00Bonificacion Disney+ (18Ene al 17Feb) (VR S/47.37)0.000.000.00Anexo 2: 9924804196\nDescuentos y Bonificaciones Inafectos Precio de vta.IGVS/0.00Bonificacion Modem ONT Premium (18Ene al 17Feb) (VRS/29.90) 0.000.000.00Detalle del recibo - N° S5AA-0077300973\nRedondeo Precio de vta.IGVS/0.00Redondeo del mes Actual-0.090.00-0.09Redondeo del mes Anterior0.090.000.09SubtotalS/135.51IGV (18%)S/24.39Total facturadoS/159.90\n\n--- Page 3 ---\nConceptos facturablesCargos fijos mensualesCargo mensual facturado al cliente por el plan contratadopara los servicios de voz y datos. Cargo fijo proporcionaldel plan desde la fecha de inicio del servicio hasta elsiguiente cierre de facturaciónCargos por llamadas adicionalesCargos por tráfico de voz, datos, mensajes de texto queno se encuentran comprendidos dentro del cargo fijomensual.Larga distancia: cargo adicional por llamada de largadistancia nacional o internacionalKB internet y multimedia: navegación en internet ytráfico por descarga de aplicativosKB transmisión de datos: envío y recepción de datos.Roaming internacional: cargo por llamadas efectuadas yrecibidas en el extranjero\nDetalle de documentos afectos al IGVCargo por Reconexión: cargo facturado si el clientecancela un recibo después de habérsele cortado pordeuda.Cargo por Reconexión de corte APC (a pedido de cliente):cargo facturado al efectuarse la reactivación del serviciode la línea luego de cumplirse el plazo de suspensión.Cargo por llamadas a operadoras rurales: llamadasrealizadas a teléfonos fijos rurales como Gilat to Home,Valtron, Claro Rural, Integratel Rural o a teléfonos satelitalescomo Tesam.Renta fraccionaria por cambio de plan: cargo facturado sidurante el ciclo de la facturación el cliente cambió a unplan tarifario de cargo fijo mayor al que tenía.\nLugares de pagoBancos y agentesBBVA ContinentalBanco PichinchaBCPBanco de la NaciónBanBifInterbankScotiabank\nOtrosAgente Multibanco KASNETMultibancoFullcargaRed Digital\nMetroWongWestern Union\nAlgunos lugares de pago presenciales pueden aplicar cobro de comisión de acuerdo a sus tarifarios vigentes.Puede realizar su pago de forma rápida y segura en el App Mi Movistar, YAPE o App o Web de su banco.\nRecuerda que también puede afiliar su reciboMovistar al débito automático, más info :http://smvst.com/DATMayor información sobre lugares de pago en www.movistar.com.pe¿Qué es el recibo digital?\nEs un servicio gratuito que ofrece Integratel, con el que podrá recibir mensualmente su recibo en formato PDF alcorreo electrónico que ust ...

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langgraph.checkpoint.sqlite import SqliteSaver

# memory = SqliteSaver.from_conn_string(":memory:")
prompt = """You are a smart invoice parsing assistant. \
You will be provided with text extracted from an invoice. \
The original invoice may have been in PDF or image format, \
but you will only receive the text extracted from the original format \
what you will return is a JSON formatted string with the following information from the \
extracted invoice's text:\
    - date: The date of the invoice with format DD-MM-YYYY or MM-YYYY if day is not present
    - The expiry date of the invoice (for payment, float-type, IMPORTANT:do not round!)
    - The amount to pay
IMPORTANT: Make sure the the output is a valid JSON string and nothing else, just the \
invoice's requested information in JSON format.
"""
model = ChatGoogleGenerativeAI(model=MODEL)
messages = [
    SystemMessage(content=prompt),
    HumanMessage(content=f"""Here is extracted text from a PDF:

{invoice_text}

"""),
]
thread = {"configurable": {"thread_id": "1"}}

# %%
agent_state = None
with SqliteSaver.from_conn_string(":memory:") as memory:
    # abot = LangGraphAgent(model, [], thread_id="3",system=prompt, checkpointer=memory)
    # agent_state = abot.query_stream("What is the last report on weather in Los Angeles?")
    pass
# Out:
# 2026-01-21 17:40:22,101::DEBUG::httpcore.connection::connect_tcp.started host='generativelanguage.googleapis.com' port=443 local_address=None timeout=None socket_options=None
# 2026-01-21 17:40:22,208::DEBUG::httpcore.connection::connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7c20868ee4d0>
# 2026-01-21 17:40:22,209::DEBUG::httpcore.connection::start_tls.started ssl_context=<ssl.SSLContext object at 0x7c20870edc70> server_hostname='generativelanguage.googleapis.com' timeout=None
# 2026-01-21 17:40:22,253::DEBUG::httpcore.connection::start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7c20b408b090>
# 2026-01-21 17:40:22,254::DEBUG::httpcore.http11::send_request_headers.started request=<Request [b'POST']>
# 2026-01-21 17:40:22,255::DEBUG::httpcore.http11::send_request_headers.complete
# 2026-01-21 17:40:22,255::DEBUG::httpcore.http11::send_request_body.started request=<Request [b'POST']>
# 2026-01-21 17:40:22,257::DEBUG::httpcore.http11::send_request_body.complete
# 2026-01-21 17:40:22,257::DEBUG::httpcore.http11::receive_response_headers.started request=<Request [b'POST']>
# 2026-01-21 17:40:24,347::DEBUG::httpcore.http11::receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json; charset=UTF-8'), (b'Vary', b'Origin'), (b'Vary', b'X-Origin'), (b'Vary', b'Referer'), (b'Content-Encoding', b'gzip'), (b'Date', b'Wed, 21 Jan 2026 22:40:24 GMT'), (b'Server', b'scaffolding on HTTPServer2'), (b'X-XSS-Protection', b'0'), (b'X-Frame-Options', b'SAMEORIGIN'), (b'X-Content-Type-Options', b'nosniff'), (b'Server-Timing', b'gfet4t7; dur=2053'), (b'Alt-Svc', b'h3=":443"; ma=2592000,h3-29=":443"; ma=2592000'), (b'Transfer-Encoding', b'chunked')])
# 2026-01-21 17:40:24,348::INFO::httpx::HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash:generateContent "HTTP/1.1 200 OK"
# 2026-01-21 17:40:24,349::DEBUG::httpcore.http11::receive_response_body.started request=<Request [b'POST']>
# 2026-01-21 17:40:24,351::DEBUG::httpcore.http11::receive_response_body.complete
# 2026-01-21 17:40:24,351::DEBUG::httpcore.http11::response_closed.started
# 2026-01-21 17:40:24,352::DEBUG::httpcore.http11::response_closed.complete
# 2026-01-21 17:40:24,355::INFO::app.adapters.langgraph_agent::[AIMessage(content='', additional_kwargs={'function_call': {'name': 'tavily_search', 'arguments': '{"query": "weather in Los Angeles", "time_range": "day"}'}, '__gemini_function_call_thought_signatures__': {'63403ee0-3b31-4cd9-8035-88edf688c87c': '...'}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019be2b7-4c50-74d3-b984-5c0823c49af8-0', tool_calls=[{'name': 'tavily_search', 'args': {'query': 'weather in Los Angeles', 'time_range': 'day'}, 'id': '63403ee0-3b31-4cd9-8035-88edf688c87c', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1564, 'output_tokens': 106, 'total_tokens': 1670, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 79}})]
# 2026-01-21 17:40:24,356::INFO::app.adapters.langgraph_agent::Calling {'name': 'tavily_search', 'args': {'query': 'weather in Los Angeles', 'time_range': 'day'}, 'id': '63403ee0-3b31-4cd9-8035-88edf688c87c', 'type': 'tool_call'}
# 2026-01-21 17:40:24,359::DEBUG::urllib3.connectionpool::Starting new HTTPS connection (1): api.tavily.com:443
# 2026-01-21 17:40:26,578::DEBUG::urllib3.connectionpool::https://api.tavily.com:443 "POST /search HTTP/1.1" 200 2467
# 2026-01-21 17:40:26,580::INFO::app.adapters.langgraph_agent::Finished executing action/s. Going back to the model
# 2026-01-21 17:40:26,581::INFO::app.adapters.langgraph_agent::[ToolMessage(content='{\'query\': \'weather in Los Angeles\', \'follow_up_questions\': None, \'answer\': None, \'images\': [], \'results\': [{\'title\': \'Weather in Los Angeles\', \'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'Los Angeles\', \'region\': \'California\', \'country\': \'United States of America\', \'lat\': 34.0522, \'lon\': -118.2428, \'tz_id\': \'America/Los_Angeles\', \'localtime_epoch\': 1769035239, \'localtime\': \'2026-01-21 14:40\'}, \'current\': {\'last_updated_epoch\': 1769034600, \'last_updated\': \'2026-01-21 14:30\', \'temp_c\': 19.1, \'temp_f\': 66.4, \'is_day\': 1, \'condition\': {\'text\': \'Sunny\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/day/113.png\', \'code\': 1000}, \'wind_mph\': 6.3, \'wind_kph\': 10.1, \'wind_degree\': 232, \'wind_dir\': \'SW\', \'pressure_mb\': 1018.0, \'pressure_in\': 30.05, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 52, \'cloud\': 0, \'feelslike_c\': 19.1, \'feelslike_f\': 66.4, \'windchill_c\': 21.2, \'windchill_f\': 70.2, \'heatindex_c\': 23.2, \'heatindex_f\': 73.8, \'dewpoint_c\': 12.5, \'dewpoint_f\': 54.4, \'vis_km\': 13.0, \'vis_miles\': 8.0, \'uv\': 1.2, \'gust_mph\': 7.2, \'gust_kph\': 11.6}}", \'score\': 0.9997548, \'raw_content\': None}, {\'url\': \'https://www.youtube.com/shorts/vrok9DL0dkM\', \'title\': \'Your 21 January 2026 weather update for Los Angeles\', \'content\': "Your 21 January 2026 weather update for Los Angeles - YouTube. Home HomeShorts ShortsSubscriptions SubscriptionsYou You. Your 21 January 2026 weather update for Los Angeles. If playback doesn\'t begin shortly, try restarting your device. An error occurred while retrieving sharing information. Your 21 January 2026 weather update for Los Angeles. Top Show featured commentsNewest Show recent comments, including potential spam. Your 21 January 2026 weather update for Los Angeles. ☁️ Weather 21 January 2026 in Los Angeles (United States): Cloudy, 16°C. Wind 9 km/h, UV 3, rain 0 mm. #Shorts#Weatheravenue, #LosAngeles, #UnitedStates, #LosAngelesweather, #Cloudy, #Sun, #Rain, #Storm…...more. Image 11: Go to video. Your 21 January 2026 weather update for Los Angeles. Image 12: Go to channel. If playback doesn\'t begin shortly, try restarting your device. Videos you watch may be added to the TV\'s watch history and influence TV recommendations. To avoid this, cancel and sign in to YouTube on your computer. An error occurred while retrieving sharing information. [](https://www.youtube.com/shorts/vrok9DL0dkM).", \'score\': 0.9997154, \'raw_content\': None}], \'response_time\': 1.83, \'request_id\': \'5ea6aa87-dfab-4f9a-a974-3a035e5a4879\'}', name='tavily_search', tool_call_id='63403ee0-3b31-4cd9-8035-88edf688c87c')]
# 2026-01-21 17:40:26,587::DEBUG::httpcore.http11::send_request_headers.started request=<Request [b'POST']>
# 2026-01-21 17:40:26,588::DEBUG::httpcore.http11::send_request_headers.complete
# 2026-01-21 17:40:26,588::DEBUG::httpcore.http11::send_request_body.started request=<Request [b'POST']>
# 2026-01-21 17:40:26,589::DEBUG::httpcore.http11::send_request_body.complete
# 2026-01-21 17:40:26,589::DEBUG::httpcore.http11::receive_response_headers.started request=<Request [b'POST']>
# 2026-01-21 17:40:29,062::DEBUG::httpcore.http11::receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json; charset=UTF-8'), (b'Vary', b'Origin'), (b'Vary', b'X-Origin'), (b'Vary', b'Referer'), (b'Content-Encoding', b'gzip'), (b'Date', b'Wed, 21 Jan 2026 22:40:28 GMT'), (b'Server', b'scaffolding on HTTPServer2'), (b'X-XSS-Protection', b'0'), (b'X-Frame-Options', b'SAMEORIGIN'), (b'X-Content-Type-Options', b'nosniff'), (b'Server-Timing', b'gfet4t7; dur=2435'), (b'Alt-Svc', b'h3=":443"; ma=2592000,h3-29=":443"; ma=2592000'), (b'Transfer-Encoding', b'chunked')])
# 2026-01-21 17:40:29,062::INFO::httpx::HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash:generateContent "HTTP/1.1 200 OK"
# 2026-01-21 17:40:29,063::DEBUG::httpcore.http11::receive_response_body.started request=<Request [b'POST']>
# 2026-01-21 17:40:29,065::DEBUG::httpcore.http11::receive_response_body.complete
# 2026-01-21 17:40:29,065::DEBUG::httpcore.http11::response_closed.started
# 2026-01-21 17:40:29,066::DEBUG::httpcore.http11::response_closed.complete
# 2026-01-21 17:40:29,068::INFO::app.adapters.langgraph_agent::[AIMessage(content='', additional_kwargs={'function_call': {'name': 'tavily_search', 'arguments': '{"query": "current weather in Los Angeles"}'}, '__gemini_function_call_thought_signatures__': {'8c8d6faf-5fa2-40a2-b9e9-cebd1757fe7a': '...'}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019be2b7-5dd7-76d0-8a05-258b1b077313-0', tool_calls=[{'name': 'tavily_search', 'args': {'query': 'current weather in Los Angeles'}, 'id': '8c8d6faf-5fa2-40a2-b9e9-cebd1757fe7a', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 2652, 'output_tokens': 144, 'total_tokens': 2796, 'input_token_details': {'cache_read': 857}, 'output_token_details': {'reasoning': 123}})]
# 2026-01-21 17:40:29,069::INFO::app.adapters.langgraph_agent::Calling {'name': 'tavily_search', 'args': {'query': 'current weather in Los Angeles'}, 'id': '8c8d6faf-5fa2-40a2-b9e9-cebd1757fe7a', 'type': 'tool_call'}
# 2026-01-21 17:40:29,071::DEBUG::urllib3.connectionpool::Starting new HTTPS connection (1): api.tavily.com:443
# 2026-01-21 17:40:30,949::DEBUG::urllib3.connectionpool::https://api.tavily.com:443 "POST /search HTTP/1.1" 200 1497
# 2026-01-21 17:40:30,951::INFO::app.adapters.langgraph_agent::Finished executing action/s. Going back to the model
# 2026-01-21 17:40:30,952::INFO::app.adapters.langgraph_agent::[ToolMessage(content='{\'query\': \'current weather in Los Angeles\', \'follow_up_questions\': None, \'answer\': None, \'images\': [], \'results\': [{\'title\': \'Weather in Los Angeles\', \'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'Los Angeles\', \'region\': \'California\', \'country\': \'United States of America\', \'lat\': 34.0522, \'lon\': -118.2428, \'tz_id\': \'America/Los_Angeles\', \'localtime_epoch\': 1769035239, \'localtime\': \'2026-01-21 14:40\'}, \'current\': {\'last_updated_epoch\': 1769034600, \'last_updated\': \'2026-01-21 14:30\', \'temp_c\': 19.1, \'temp_f\': 66.4, \'is_day\': 1, \'condition\': {\'text\': \'Sunny\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/day/113.png\', \'code\': 1000}, \'wind_mph\': 6.3, \'wind_kph\': 10.1, \'wind_degree\': 232, \'wind_dir\': \'SW\', \'pressure_mb\': 1018.0, \'pressure_in\': 30.05, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 52, \'cloud\': 0, \'feelslike_c\': 19.1, \'feelslike_f\': 66.4, \'windchill_c\': 21.2, \'windchill_f\': 70.2, \'heatindex_c\': 23.2, \'heatindex_f\': 73.8, \'dewpoint_c\': 12.5, \'dewpoint_f\': 54.4, \'vis_km\': 13.0, \'vis_miles\': 8.0, \'uv\': 1.2, \'gust_mph\': 7.2, \'gust_kph\': 11.6}}", \'score\': 0.9999626, \'raw_content\': None}, {\'url\': \'https://www.youtube.com/shorts/vrok9DL0dkM\', \'title\': \'Your 21 January 2026 weather update for Los Angeles - YouTube\', \'content\': \'Weather 21 January 2026 in Los Angeles (United States): Cloudy, 16°C. Wind 9 km/h, UV 3, rain 0 mm. Subscribe for local forecasts!\', \'score\': 0.9998634, \'raw_content\': None}], \'response_time\': 1.55, \'request_id\': \'4ffc211b-85ca-4b06-95cd-0b0e5fd01d1e\'}', name='tavily_search', tool_call_id='8c8d6faf-5fa2-40a2-b9e9-cebd1757fe7a')]
# 2026-01-21 17:40:30,958::DEBUG::httpcore.http11::send_request_headers.started request=<Request [b'POST']>
# 2026-01-21 17:40:30,959::DEBUG::httpcore.http11::send_request_headers.complete
# 2026-01-21 17:40:30,959::DEBUG::httpcore.http11::send_request_body.started request=<Request [b'POST']>
# 2026-01-21 17:40:30,960::DEBUG::httpcore.http11::send_request_body.complete
# 2026-01-21 17:40:30,960::DEBUG::httpcore.http11::receive_response_headers.started request=<Request [b'POST']>
# 2026-01-21 17:40:31,322::DEBUG::httpcore.http11::receive_response_headers.complete return_value=(b'HTTP/1.1', 429, b'Too Many Requests', [(b'Vary', b'Origin'), (b'Vary', b'X-Origin'), (b'Vary', b'Referer'), (b'Content-Type', b'application/json; charset=UTF-8'), (b'Content-Encoding', b'gzip'), (b'Date', b'Wed, 21 Jan 2026 22:40:31 GMT'), (b'Server', b'scaffolding on HTTPServer2'), (b'X-XSS-Protection', b'0'), (b'X-Frame-Options', b'SAMEORIGIN'), (b'X-Content-Type-Options', b'nosniff'), (b'Server-Timing', b'gfet4t7; dur=324'), (b'Alt-Svc', b'h3=":443"; ma=2592000,h3-29=":443"; ma=2592000'), (b'Transfer-Encoding', b'chunked')])
# 2026-01-21 17:40:31,323::INFO::httpx::HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash:generateContent "HTTP/1.1 429 Too Many Requests"
# 2026-01-21 17:40:31,323::DEBUG::httpcore.http11::receive_response_body.started request=<Request [b'POST']>
# 2026-01-21 17:40:31,325::DEBUG::httpcore.http11::receive_response_body.complete
# 2026-01-21 17:40:31,325::DEBUG::httpcore.http11::response_closed.started
# 2026-01-21 17:40:31,325::DEBUG::httpcore.http11::response_closed.complete
# 2026-01-21 17:40:31,326::INFO::google_genai._api_client::Retrying google.genai._api_client.BaseApiClient._request_once in 1.0705596705134166 seconds as it raised ClientError: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash\nPlease retry in 28.840917234s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'model': 'gemini-2.5-flash', 'location': 'global'}, 'quotaValue': '20'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '28s'}]}}.
# 2026-01-21 17:40:32,398::DEBUG::httpcore.http11::send_request_headers.started request=<Request [b'POST']>
# 2026-01-21 17:40:32,399::DEBUG::httpcore.http11::send_request_headers.complete
# 2026-01-21 17:40:32,399::DEBUG::httpcore.http11::send_request_body.started request=<Request [b'POST']>
# 2026-01-21 17:40:32,400::DEBUG::httpcore.http11::send_request_body.complete
# 2026-01-21 17:40:32,400::DEBUG::httpcore.http11::receive_response_headers.started request=<Request [b'POST']>
# 2026-01-21 17:40:32,735::DEBUG::httpcore.http11::receive_response_headers.complete return_value=(b'HTTP/1.1', 429, b'Too Many Requests', [(b'Vary', b'Origin'), (b'Vary', b'X-Origin'), (b'Vary', b'Referer'), (b'Content-Type', b'application/json; charset=UTF-8'), (b'Content-Encoding', b'gzip'), (b'Date', b'Wed, 21 Jan 2026 22:40:32 GMT'), (b'Server', b'scaffolding on HTTPServer2'), (b'X-XSS-Protection', b'0'), (b'X-Frame-Options', b'SAMEORIGIN'), (b'X-Content-Type-Options', b'nosniff'), (b'Server-Timing', b'gfet4t7; dur=297'), (b'Alt-Svc', b'h3=":443"; ma=2592000,h3-29=":443"; ma=2592000'), (b'Transfer-Encoding', b'chunked')])
# 2026-01-21 17:40:32,736::INFO::httpx::HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash:generateContent "HTTP/1.1 429 Too Many Requests"
# 2026-01-21 17:40:32,737::DEBUG::httpcore.http11::receive_response_body.started request=<Request [b'POST']>
# 2026-01-21 17:40:32,738::DEBUG::httpcore.http11::receive_response_body.complete
# 2026-01-21 17:40:32,738::DEBUG::httpcore.http11::response_closed.started
# 2026-01-21 17:40:32,739::DEBUG::httpcore.http11::response_closed.complete
# 2026-01-21 17:40:32,740::INFO::google_genai._api_client::Retrying google.genai._api_client.BaseApiClient._request_once in 2.581162665391227 seconds as it raised ClientError: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash\nPlease retry in 27.407966105s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'model': 'gemini-2.5-flash', 'location': 'global'}, 'quotaValue': '20'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '27s'}]}}.
# 2026-01-21 17:40:35,322::DEBUG::httpcore.http11::send_request_headers.started request=<Request [b'POST']>
# 2026-01-21 17:40:35,323::DEBUG::httpcore.http11::send_request_headers.complete
# 2026-01-21 17:40:35,324::DEBUG::httpcore.http11::send_request_body.started request=<Request [b'POST']>
# 2026-01-21 17:40:35,325::DEBUG::httpcore.http11::send_request_body.complete
# 2026-01-21 17:40:35,325::DEBUG::httpcore.http11::receive_response_headers.started request=<Request [b'POST']>
# 2026-01-21 17:40:35,698::DEBUG::httpcore.http11::receive_response_headers.complete return_value=(b'HTTP/1.1', 429, b'Too Many Requests', [(b'Vary', b'Origin'), (b'Vary', b'X-Origin'), (b'Vary', b'Referer'), (b'Content-Type', b'application/json; charset=UTF-8'), (b'Content-Encoding', b'gzip'), (b'Date', b'Wed, 21 Jan 2026 22:40:35 GMT'), (b'Server', b'scaffolding on HTTPServer2'), (b'X-XSS-Protection', b'0'), (b'X-Frame-Options', b'SAMEORIGIN'), (b'X-Content-Type-Options', b'nosniff'), (b'Server-Timing', b'gfet4t7; dur=336'), (b'Alt-Svc', b'h3=":443"; ma=2592000,h3-29=":443"; ma=2592000'), (b'Transfer-Encoding', b'chunked')])
# 2026-01-21 17:40:35,699::INFO::httpx::HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash:generateContent "HTTP/1.1 429 Too Many Requests"
# 2026-01-21 17:40:35,700::DEBUG::httpcore.http11::receive_response_body.started request=<Request [b'POST']>
# 2026-01-21 17:40:35,701::DEBUG::httpcore.http11::receive_response_body.complete
# 2026-01-21 17:40:35,701::DEBUG::httpcore.http11::response_closed.started
# 2026-01-21 17:40:35,701::DEBUG::httpcore.http11::response_closed.complete
# 2026-01-21 17:40:35,702::INFO::google_genai._api_client::Retrying google.genai._api_client.BaseApiClient._request_once in 4.3248374767281685 seconds as it raised ClientError: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash\nPlease retry in 24.472840113s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'model': 'gemini-2.5-flash', 'location': 'global'}, 'quotaValue': '20'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '24s'}]}}.
# 2026-01-21 17:40:40,028::DEBUG::httpcore.http11::send_request_headers.started request=<Request [b'POST']>
# 2026-01-21 17:40:40,029::DEBUG::httpcore.http11::send_request_headers.complete
# 2026-01-21 17:40:40,030::DEBUG::httpcore.http11::send_request_body.started request=<Request [b'POST']>
# 2026-01-21 17:40:40,031::DEBUG::httpcore.http11::send_request_body.complete
# 2026-01-21 17:40:40,031::DEBUG::httpcore.http11::receive_response_headers.started request=<Request [b'POST']>
# 2026-01-21 17:40:40,401::DEBUG::httpcore.http11::receive_response_headers.complete return_value=(b'HTTP/1.1', 429, b'Too Many Requests', [(b'Vary', b'Origin'), (b'Vary', b'X-Origin'), (b'Vary', b'Referer'), (b'Content-Type', b'application/json; charset=UTF-8'), (b'Content-Encoding', b'gzip'), (b'Date', b'Wed, 21 Jan 2026 22:40:40 GMT'), (b'Server', b'scaffolding on HTTPServer2'), (b'X-XSS-Protection', b'0'), (b'X-Frame-Options', b'SAMEORIGIN'), (b'X-Content-Type-Options', b'nosniff'), (b'Server-Timing', b'gfet4t7; dur=332'), (b'Alt-Svc', b'h3=":443"; ma=2592000,h3-29=":443"; ma=2592000'), (b'Transfer-Encoding', b'chunked')])
# 2026-01-21 17:40:40,401::INFO::httpx::HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash:generateContent "HTTP/1.1 429 Too Many Requests"
# 2026-01-21 17:40:40,402::DEBUG::httpcore.http11::receive_response_body.started request=<Request [b'POST']>
# 2026-01-21 17:40:40,404::DEBUG::httpcore.http11::receive_response_body.complete
# 2026-01-21 17:40:40,404::DEBUG::httpcore.http11::response_closed.started
# 2026-01-21 17:40:40,405::DEBUG::httpcore.http11::response_closed.complete
# 2026-01-21 17:40:40,405::INFO::google_genai._api_client::Retrying google.genai._api_client.BaseApiClient._request_once in 8.919025378791439 seconds as it raised ClientError: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash\nPlease retry in 19.777929735s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash'}, 'quotaValue': '20'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '19s'}]}}.
# 2026-01-21 17:40:49,325::DEBUG::httpcore.connection::close.started
# 2026-01-21 17:40:49,326::DEBUG::httpcore.connection::close.complete
# 2026-01-21 17:40:49,326::DEBUG::httpcore.connection::connect_tcp.started host='generativelanguage.googleapis.com' port=443 local_address=None timeout=None socket_options=None
# 2026-01-21 17:40:49,364::DEBUG::httpcore.connection::connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7c20857b2410>
# 2026-01-21 17:40:49,365::DEBUG::httpcore.connection::start_tls.started ssl_context=<ssl.SSLContext object at 0x7c20870edc70> server_hostname='generativelanguage.googleapis.com' timeout=None
# 2026-01-21 17:40:49,407::DEBUG::httpcore.connection::start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7c208697f5d0>
# 2026-01-21 17:40:49,408::DEBUG::httpcore.http11::send_request_headers.started request=<Request [b'POST']>
# 2026-01-21 17:40:49,409::DEBUG::httpcore.http11::send_request_headers.complete
# 2026-01-21 17:40:49,409::DEBUG::httpcore.http11::send_request_body.started request=<Request [b'POST']>
# 2026-01-21 17:40:49,410::DEBUG::httpcore.http11::send_request_body.complete
# 2026-01-21 17:40:49,411::DEBUG::httpcore.http11::receive_response_headers.started request=<Request [b'POST']>
# 2026-01-21 17:40:53,416::DEBUG::httpcore.http11::receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json; charset=UTF-8'), (b'Vary', b'Origin'), (b'Vary', b'X-Origin'), (b'Vary', b'Referer'), (b'Content-Encoding', b'gzip'), (b'Date', b'Wed, 21 Jan 2026 22:40:53 GMT'), (b'Server', b'scaffolding on HTTPServer2'), (b'X-XSS-Protection', b'0'), (b'X-Frame-Options', b'SAMEORIGIN'), (b'X-Content-Type-Options', b'nosniff'), (b'Server-Timing', b'gfet4t7; dur=3967'), (b'Alt-Svc', b'h3=":443"; ma=2592000,h3-29=":443"; ma=2592000'), (b'Transfer-Encoding', b'chunked')])
# 2026-01-21 17:40:53,417::INFO::httpx::HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash:generateContent "HTTP/1.1 200 OK"
# 2026-01-21 17:40:53,418::DEBUG::httpcore.http11::receive_response_body.started request=<Request [b'POST']>
# 2026-01-21 17:40:53,419::DEBUG::httpcore.http11::receive_response_body.complete
# 2026-01-21 17:40:53,420::DEBUG::httpcore.http11::response_closed.started
# 2026-01-21 17:40:53,420::DEBUG::httpcore.http11::response_closed.complete
# 2026-01-21 17:40:53,423::INFO::app.adapters.langgraph_agent::[AIMessage(content='', additional_kwargs={'function_call': {'name': 'tavily_search', 'arguments': '{"query": "real-time current weather in Los Angeles", "exclude_domains": ["weatherapi.com"]}'}, '__gemini_function_call_thought_signatures__': {'fba4bd59-56f5-46cf-b827-37d45a3087d8': '...'}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019be2b7-6eea-7761-8226-962b60630354-0', tool_calls=[{'name': 'tavily_search', 'args': {'query': 'real-time current weather in Los Angeles', 'exclude_domains': ['weatherapi.com']}, 'id': 'fba4bd59-56f5-46cf-b827-37d45a3087d8', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 3482, 'output_tokens': 163, 'total_tokens': 3645, 'input_token_details': {'cache_read': 2585}, 'output_token_details': {'reasoning': 129}})]
# 2026-01-21 17:40:53,423::INFO::app.adapters.langgraph_agent::Calling {'name': 'tavily_search', 'args': {'query': 'real-time current weather in Los Angeles', 'exclude_domains': ['weatherapi.com']}, 'id': 'fba4bd59-56f5-46cf-b827-37d45a3087d8', 'type': 'tool_call'}
# 2026-01-21 17:40:53,425::DEBUG::urllib3.connectionpool::Starting new HTTPS connection (1): api.tavily.com:443
# 2026-01-21 17:40:55,354::DEBUG::urllib3.connectionpool::https://api.tavily.com:443 "POST /search HTTP/1.1" 200 1468
# 2026-01-21 17:40:55,356::INFO::app.adapters.langgraph_agent::Finished executing action/s. Going back to the model
# 2026-01-21 17:40:55,357::INFO::app.adapters.langgraph_agent::[ToolMessage(content='{\'query\': \'real-time current weather in Los Angeles\', \'follow_up_questions\': None, \'answer\': None, \'images\': [], \'results\': [{\'title\': \'Weather in Los Angeles\', \'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'Los Angeles\', \'region\': \'California\', \'country\': \'United States of America\', \'lat\': 34.0522, \'lon\': -118.2428, \'tz_id\': \'America/Los_Angeles\', \'localtime_epoch\': 1769035239, \'localtime\': \'2026-01-21 14:40\'}, \'current\': {\'last_updated_epoch\': 1769034600, \'last_updated\': \'2026-01-21 14:30\', \'temp_c\': 19.1, \'temp_f\': 66.4, \'is_day\': 1, \'condition\': {\'text\': \'Sunny\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/day/113.png\', \'code\': 1000}, \'wind_mph\': 6.3, \'wind_kph\': 10.1, \'wind_degree\': 232, \'wind_dir\': \'SW\', \'pressure_mb\': 1018.0, \'pressure_in\': 30.05, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 52, \'cloud\': 0, \'feelslike_c\': 19.1, \'feelslike_f\': 66.4, \'windchill_c\': 21.2, \'windchill_f\': 70.2, \'heatindex_c\': 23.2, \'heatindex_f\': 73.8, \'dewpoint_c\': 12.5, \'dewpoint_f\': 54.4, \'vis_km\': 13.0, \'vis_miles\': 8.0, \'uv\': 1.2, \'gust_mph\': 7.2, \'gust_kph\': 11.6}}", \'score\': 0.9986538, \'raw_content\': None}, {\'url\': \'https://www.timeanddate.com/weather/usa/los-angeles\', \'title\': \'Weather for Los Angeles, California, USA\', \'content\': \'Weather in Los Angeles, California, USA ; Jan 21, 2026 at 6:53 am · 5 mi · 30.08 "Hg · 87% · 53 °F\', \'score\': 0.9983516, \'raw_content\': None}], \'response_time\': 1.54, \'request_id\': \'0a96a04b-f0c8-456a-9e85-3443db7fda8a\'}', name='tavily_search', tool_call_id='fba4bd59-56f5-46cf-b827-37d45a3087d8')]
# 2026-01-21 17:40:55,363::DEBUG::httpcore.http11::send_request_headers.started request=<Request [b'POST']>
# 2026-01-21 17:40:55,364::DEBUG::httpcore.http11::send_request_headers.complete
# 2026-01-21 17:40:55,365::DEBUG::httpcore.http11::send_request_body.started request=<Request [b'POST']>
# 2026-01-21 17:40:55,366::DEBUG::httpcore.http11::send_request_body.complete
# 2026-01-21 17:40:55,366::DEBUG::httpcore.http11::receive_response_headers.started request=<Request [b'POST']>
# 2026-01-21 17:40:55,706::DEBUG::httpcore.http11::receive_response_headers.complete return_value=(b'HTTP/1.1', 429, b'Too Many Requests', [(b'Vary', b'Origin'), (b'Vary', b'X-Origin'), (b'Vary', b'Referer'), (b'Content-Type', b'application/json; charset=UTF-8'), (b'Content-Encoding', b'gzip'), (b'Date', b'Wed, 21 Jan 2026 22:40:55 GMT'), (b'Server', b'scaffolding on HTTPServer2'), (b'X-XSS-Protection', b'0'), (b'X-Frame-Options', b'SAMEORIGIN'), (b'X-Content-Type-Options', b'nosniff'), (b'Server-Timing', b'gfet4t7; dur=301'), (b'Alt-Svc', b'h3=":443"; ma=2592000,h3-29=":443"; ma=2592000'), (b'Transfer-Encoding', b'chunked')])
# 2026-01-21 17:40:55,707::INFO::httpx::HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash:generateContent "HTTP/1.1 429 Too Many Requests"
# 2026-01-21 17:40:55,708::DEBUG::httpcore.http11::receive_response_body.started request=<Request [b'POST']>
# 2026-01-21 17:40:55,709::DEBUG::httpcore.http11::receive_response_body.complete
# 2026-01-21 17:40:55,710::DEBUG::httpcore.http11::response_closed.started
# 2026-01-21 17:40:55,710::DEBUG::httpcore.http11::response_closed.complete
# 2026-01-21 17:40:55,710::INFO::google_genai._api_client::Retrying google.genai._api_client.BaseApiClient._request_once in 1.733921257275496 seconds as it raised ClientError: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash\nPlease retry in 4.440366575s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash'}, 'quotaValue': '20'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '4s'}]}}.
# 2026-01-21 17:40:57,445::DEBUG::httpcore.http11::send_request_headers.started request=<Request [b'POST']>
# 2026-01-21 17:40:57,446::DEBUG::httpcore.http11::send_request_headers.complete
# 2026-01-21 17:40:57,447::DEBUG::httpcore.http11::send_request_body.started request=<Request [b'POST']>
# 2026-01-21 17:40:57,448::DEBUG::httpcore.http11::send_request_body.complete
# 2026-01-21 17:40:57,448::DEBUG::httpcore.http11::receive_response_headers.started request=<Request [b'POST']>
# 2026-01-21 17:40:57,819::DEBUG::httpcore.http11::receive_response_headers.complete return_value=(b'HTTP/1.1', 429, b'Too Many Requests', [(b'Vary', b'Origin'), (b'Vary', b'X-Origin'), (b'Vary', b'Referer'), (b'Content-Type', b'application/json; charset=UTF-8'), (b'Content-Encoding', b'gzip'), (b'Date', b'Wed, 21 Jan 2026 22:40:57 GMT'), (b'Server', b'scaffolding on HTTPServer2'), (b'X-XSS-Protection', b'0'), (b'X-Frame-Options', b'SAMEORIGIN'), (b'X-Content-Type-Options', b'nosniff'), (b'Server-Timing', b'gfet4t7; dur=336'), (b'Alt-Svc', b'h3=":443"; ma=2592000,h3-29=":443"; ma=2592000'), (b'Transfer-Encoding', b'chunked')])
# 2026-01-21 17:40:57,820::INFO::httpx::HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash:generateContent "HTTP/1.1 429 Too Many Requests"
# 2026-01-21 17:40:57,820::DEBUG::httpcore.http11::receive_response_body.started request=<Request [b'POST']>
# 2026-01-21 17:40:57,822::DEBUG::httpcore.http11::receive_response_body.complete
# 2026-01-21 17:40:57,822::DEBUG::httpcore.http11::response_closed.started
# 2026-01-21 17:40:57,823::DEBUG::httpcore.http11::response_closed.complete
# 2026-01-21 17:40:57,824::INFO::google_genai._api_client::Retrying google.genai._api_client.BaseApiClient._request_once in 2.1115841072345773 seconds as it raised ClientError: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash\nPlease retry in 2.350877875s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash'}, 'quotaValue': '20'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '2s'}]}}.
# 2026-01-21 17:40:59,936::DEBUG::httpcore.http11::send_request_headers.started request=<Request [b'POST']>
# 2026-01-21 17:40:59,938::DEBUG::httpcore.http11::send_request_headers.complete
# 2026-01-21 17:40:59,938::DEBUG::httpcore.http11::send_request_body.started request=<Request [b'POST']>
# 2026-01-21 17:40:59,939::DEBUG::httpcore.http11::send_request_body.complete
# 2026-01-21 17:40:59,939::DEBUG::httpcore.http11::receive_response_headers.started request=<Request [b'POST']>
# 2026-01-21 17:41:00,312::DEBUG::httpcore.http11::receive_response_headers.complete return_value=(b'HTTP/1.1', 429, b'Too Many Requests', [(b'Vary', b'Origin'), (b'Vary', b'X-Origin'), (b'Vary', b'Referer'), (b'Content-Type', b'application/json; charset=UTF-8'), (b'Content-Encoding', b'gzip'), (b'Date', b'Wed, 21 Jan 2026 22:41:00 GMT'), (b'Server', b'scaffolding on HTTPServer2'), (b'X-XSS-Protection', b'0'), (b'X-Frame-Options', b'SAMEORIGIN'), (b'X-Content-Type-Options', b'nosniff'), (b'Server-Timing', b'gfet4t7; dur=338'), (b'Alt-Svc', b'h3=":443"; ma=2592000,h3-29=":443"; ma=2592000'), (b'Transfer-Encoding', b'chunked')])
# 2026-01-21 17:41:00,313::INFO::httpx::HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash:generateContent "HTTP/1.1 429 Too Many Requests"
# 2026-01-21 17:41:00,313::DEBUG::httpcore.http11::receive_response_body.started request=<Request [b'POST']>
# 2026-01-21 17:41:00,314::DEBUG::httpcore.http11::receive_response_body.complete
# 2026-01-21 17:41:00,315::DEBUG::httpcore.http11::response_closed.started
# 2026-01-21 17:41:00,315::DEBUG::httpcore.http11::response_closed.complete
# 2026-01-21 17:41:00,316::INFO::google_genai._api_client::Retrying google.genai._api_client.BaseApiClient._request_once in 4.046526691376216 seconds as it raised ClientError: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash\nPlease retry in 59.865284336s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash'}, 'quotaValue': '20'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '59s'}]}}.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 4
#       2 with SqliteSaver.from_conn_string(":memory:") as memory:
#       3     abot = LangGraphAgent(model, [tool], thread_id="3",system=prompt, checkpointer=memory)
# ----> 4     agent_state = abot.query_stream("What is the last report on weather in Los Angeles?")
#
# File ~/projects/fapi01/be2/src/app/adapters/langgraph_agent.py:67, in LangGraphAgent.query_stream(self, input_query)
#      64 messages = [HumanMessage(content=input_query)]
#      65 thread = {"configurable": {"thread_id": self.thread_id}}
# ---> 67 for event in self.graph.stream({"messages": messages}, thread):
#      68     for v in event.values():
#      69         logger.info(v["messages"])
#
# File ~/projects/fapi01/be2/.venv/lib/python3.11/site-packages/langgraph/pregel/main.py:2646, in Pregel.stream(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, subgraphs, debug, **kwargs)
#    2644 for task in loop.match_cached_writes():
#    2645     loop.output_writes(task.id, task.writes, cached=True)
# -> 2646 for _ in runner.tick(
#    2647     [t for t in loop.tasks.values() if not t.writes],
#    2648     timeout=self.step_timeout,
#    2649     get_waiter=get_waiter,
#    2650     schedule_task=loop.accept_push,
#    2651 ):
#    2652     # emit output
#    2653     yield from _output(
#    2654         stream_mode, print_mode, subgraphs, stream.get, queue.Empty
#    2655     )
#    2656 loop.after_tick()
#
# File ~/projects/fapi01/be2/.venv/lib/python3.11/site-packages/langgraph/pregel/_runner.py:167, in PregelRunner.tick(self, tasks, reraise, timeout, retry_policy, get_waiter, schedule_task)
#     165 t = tasks[0]
#     166 try:
# --> 167     run_with_retry(
#     168         t,
#     169         retry_policy,
#     170         configurable={
#     171             CONFIG_KEY_CALL: partial(
#     172                 _call,
#     173                 weakref.ref(t),
#     174                 retry_policy=retry_policy,
#     175                 futures=weakref.ref(futures),
#     176                 schedule_task=schedule_task,
#     177                 submit=self.submit,
#     178             ),
#     179         },
#     180     )
#     181     self.commit(t, None)
#     182 except Exception as exc:
#
# File ~/projects/fapi01/be2/.venv/lib/python3.11/site-packages/langgraph/pregel/_retry.py:42, in run_with_retry(task, retry_policy, configurable)
#      40     task.writes.clear()
#      41     # run the task
# ---> 42     return task.proc.invoke(task.input, config)
#      43 except ParentCommand as exc:
#      44     ns: str = config[CONF][CONFIG_KEY_CHECKPOINT_NS]
#
# File ~/projects/fapi01/be2/.venv/lib/python3.11/site-packages/langgraph/_internal/_runnable.py:656, in RunnableSeq.invoke(self, input, config, **kwargs)
#     654     # run in context
#     655     with set_config_context(config, run) as context:
# --> 656         input = context.run(step.invoke, input, config, **kwargs)
#     657 else:
#     658     input = step.invoke(input, config)
#
# File ~/projects/fapi01/be2/.venv/lib/python3.11/site-packages/langgraph/_internal/_runnable.py:400, in RunnableCallable.invoke(self, input, config, **kwargs)
#     398         run_manager.on_chain_end(ret)
#     399 else:
# --> 400     ret = self.func(*args, **kwargs)
#     401 if self.recurse and isinstance(ret, Runnable):
#     402     return ret.invoke(input, config)
#
# File ~/projects/fapi01/be2/src/app/adapters/langgraph_agent.py:44, in LangGraphAgent.call_model(self, state)
#      42 if self.system:
#      43     messages = [SystemMessage(content=self.system)] + messages
# ---> 44 message = self.model.invoke(messages)
#      45 return {"messages": [message]}
#
# File ~/projects/fapi01/be2/.venv/lib/python3.11/site-packages/langchain_core/runnables/base.py:5557, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5550 @override
#    5551 def invoke(
#    5552     self,
#    (...)   5555     **kwargs: Any | None,
#    5556 ) -> Output:
# -> 5557     return self.bound.invoke(
#    5558         input,
#    5559         self._merge_configs(config),
#    5560         **{**self.kwargs, **kwargs},
#    5561     )
#
# File ~/projects/fapi01/be2/.venv/lib/python3.11/site-packages/langchain_google_genai/chat_models.py:2535, in ChatGoogleGenerativeAI.invoke(self, input, config, code_execution, stop, **kwargs)
#    2532         msg = "Tools are already defined.code_execution tool can't be defined"
#    2533         raise ValueError(msg)
# -> 2535 return super().invoke(input, config, stop=stop, **kwargs)
#
# File ~/projects/fapi01/be2/.venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:402, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     388 @override
#     389 def invoke(
#     390     self,
#    (...)    395     **kwargs: Any,
#     396 ) -> AIMessage:
#     397     config = ensure_config(config)
#     398     return cast(
#     399         "AIMessage",
#     400         cast(
#     401             "ChatGeneration",
# --> 402             self.generate_prompt(
#     403                 [self._convert_input(input)],
#     404                 stop=stop,
#     405                 callbacks=config.get("callbacks"),
#     406                 tags=config.get("tags"),
#     407                 metadata=config.get("metadata"),
#     408                 run_name=config.get("run_name"),
#     409                 run_id=config.pop("run_id", None),
#     410                 **kwargs,
#     411             ).generations[0][0],
#     412         ).message,
#     413     )
#
# File ~/projects/fapi01/be2/.venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:1121, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1112 @override
#    1113 def generate_prompt(
#    1114     self,
#    (...)   1118     **kwargs: Any,
#    1119 ) -> LLMResult:
#    1120     prompt_messages = [p.to_messages() for p in prompts]
# -> 1121     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/projects/fapi01/be2/.venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:931, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     928 for i, m in enumerate(input_messages):
#     929     try:
#     930         results.append(
# --> 931             self._generate_with_cache(
#     932                 m,
#     933                 stop=stop,
#     934                 run_manager=run_managers[i] if run_managers else None,
#     935                 **kwargs,
#     936             )
#     937         )
#     938     except BaseException as e:
#     939         if run_managers:
#
# File ~/projects/fapi01/be2/.venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:1233, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1231     result = generate_from_stream(iter(chunks))
#    1232 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1233     result = self._generate(
#    1234         messages, stop=stop, run_manager=run_manager, **kwargs
#    1235     )
#    1236 else:
#    1237     result = self._generate(messages, stop=stop, **kwargs)
#
# File ~/projects/fapi01/be2/.venv/lib/python3.11/site-packages/langchain_google_genai/chat_models.py:3047, in ChatGoogleGenerativeAI._generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#    3034 request = self._prepare_request(
#    3035     messages,
#    3036     stop=stop,
#    (...)   3044     **kwargs,
#    3045 )
#    3046 try:
# -> 3047     response: GenerateContentResponse = self.client.models.generate_content(
#    3048         **request,
#    3049     )
#    3050 except ClientError as e:
#    3051     _handle_client_error(e, request)
#
# File ~/projects/fapi01/be2/.venv/lib/python3.11/site-packages/google/genai/models.py:5200, in Models.generate_content(self, model, contents, config)
#    5192     indices_str = ', '.join(map(str, incompatible_tools_indexes))
#    5193     logger.warning(
#    5194         'Tools at indices [%s] are not compatible with automatic function '
#    5195         'calling (AFC). AFC is disabled. If AFC is intended, please '
#    (...)   5198         indices_str,
#    5199     )
# -> 5200   return self._generate_content(
#    5201       model=model, contents=contents, config=parsed_config
#    5202   )
#    5204 remaining_remote_calls_afc = _extra_utils.get_max_remote_calls_afc(
#    5205     parsed_config
#    5206 )
#    5207 logger.info(
#    5208     f'AFC is enabled with max remote calls: {remaining_remote_calls_afc}.'
#    5209 )
#
# File ~/projects/fapi01/be2/.venv/lib/python3.11/site-packages/google/genai/models.py:3997, in Models._generate_content(self, model, contents, config)
#    3994 request_dict = _common.convert_to_dict(request_dict)
#    3995 request_dict = _common.encode_unserializable_types(request_dict)
# -> 3997 response = self._api_client.request(
#    3998     'post', path, request_dict, http_options
#    3999 )
#    4001 if config is not None and getattr(
#    4002     config, 'should_return_http_response', None
#    4003 ):
#    4004   return_value = types.GenerateContentResponse(sdk_http_response=response)
#
# File ~/projects/fapi01/be2/.venv/lib/python3.11/site-packages/google/genai/_api_client.py:1386, in BaseApiClient.request(self, http_method, path, request_dict, http_options)
#    1376 def request(
#    1377     self,
#    1378     http_method: str,
#    (...)   1381     http_options: Optional[HttpOptionsOrDict] = None,
#    1382 ) -> SdkHttpResponse:
#    1383   http_request = self._build_request(
#    1384       http_method, path, request_dict, http_options
#    1385   )
# -> 1386   response = self._request(http_request, http_options, stream=False)
#    1387   response_body = (
#    1388       response.response_stream[0] if response.response_stream else ''
#    1389   )
#    1390   return SdkHttpResponse(headers=response.headers, body=response_body)
#
# File ~/projects/fapi01/be2/.venv/lib/python3.11/site-packages/google/genai/_api_client.py:1220, in BaseApiClient._request(self, http_request, http_options, stream)
#    1218     retry_kwargs = retry_args(parameter_model.retry_options)
#    1219     retry = tenacity.Retrying(**retry_kwargs)
# -> 1220     return retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
#    1222 return self._retry(self._request_once, http_request, stream)
#
# File ~/projects/fapi01/be2/.venv/lib/python3.11/site-packages/tenacity/__init__.py:487, in Retrying.__call__(self, fn, *args, **kwargs)
#     485 elif isinstance(do, DoSleep):
#     486     retry_state.prepare_for_next_attempt()
# --> 487     self.sleep(do)
#     488 else:
#     489     return do
#
# File ~/projects/fapi01/be2/.venv/lib/python3.11/site-packages/tenacity/nap.py:31, in sleep(seconds)
#      25 def sleep(seconds: float) -> None:
#      26     """
#      27     Sleep strategy that delays execution for a given number of seconds.
#      28
#      29     This is the default strategy, and may be mocked out for unit testing.
#      30     """
# ---> 31     time.sleep(seconds)
#
# KeyboardInterrupt:
